# %%
from strym import strymread
import strym
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sea
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
data = "/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_04_30/2020-04-30-09-16-18_5FNYF6H05HB089022_CAN_Messages.csv"
dbcfile= "/home/ivory/VersionControl/Jmscslgroup/strym/examples/honda_pilot_touring_2017_can_generated.dbc"

# %%
r = strymread(csvfile=data, dbcfile=dbcfile)

# %%
r.count()

# %%
r.frequency()
# Out:
# /home/ivory/anaconda3/envs/dbn/lib/python3.7/site-packages/numpy/core/_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#      MessageID    MeanRate  MedianRate    RateStd      MaxRate    MinRate  \
# 0           57   25.745966   25.000024  12.872444   329.300777  23.903527
# 1          145  103.658655  100.019173  63.189448  2289.467249  36.796982
# 2          228  103.991301  100.009633  69.621096  2872.810959  32.283992
# 3          229  104.128671   99.978642  73.554050  2493.640904  32.460136
# 4          308  104.177729   99.981025  74.794076  3095.427306  32.408719
# ..         ...         ...         ...        ...          ...        ...
# 101       1612    1.000403    1.000039   0.005487     1.087484   0.998178
# 102       1613    1.000725    1.000012   0.011486     1.183240   0.996545
# 103       1616    1.000811    1.000080   0.012512     1.198342   0.995939
# ...

# %%
msgs464_1 = r.get_ts(464,1)

# %%
msgs464_1
# Out:
#                                        Time  Message
# Clock
# 2020-04-30 16:16:19.191863060  1.588263e+09    63.35
# 2020-04-30 16:16:19.193773985  1.588263e+09    63.33
# 2020-04-30 16:16:19.196507931  1.588263e+09    63.47
# 2020-04-30 16:16:19.198184013  1.588263e+09    63.54
# 2020-04-30 16:16:19.200067997  1.588263e+09    63.56
# ...                                     ...      ...
# 2020-04-30 16:20:33.233618975  1.588264e+09    13.64
# 2020-04-30 16:20:33.253679991  1.588264e+09    13.70
# 2020-04-30 16:20:33.274065018  1.588264e+09    13.74
# 2020-04-30 16:20:33.293877840  1.588264e+09    13.62
# 2020-04-30 16:20:33.314265013  1.588264e+09    13.56
#
# [12748 rows x 2 columns]

# %%
strym.ranalyze(msgs464_1, title="Message 464, Signal ID 1")
# Out:
# Analyzing Timestamp and Data Rate of Message 464, Signal ID 1
# Interquartile Range of Rate for Message 464, Signal ID 1 is 1.148635679815989

# %%
msgs490_1 = r.get_ts(490,1)
strym.ranalyze(msgs490_1, title="Message 490, Signal ID 1")
# Out:
# Analyzing Timestamp and Data Rate of Message 490, Signal ID 1
# Interquartile Range of Rate for Message 490, Signal ID 1 is 1.2079413490941846

# %%
msgs145_0 = r.get_ts(145,0)
strym.ranalyze(msgs145_0, title="Message 145, Signal ID 0")
# Out:
# Analyzing Timestamp and Data Rate of Message 145, Signal ID 0
# Interquartile Range of Rate for Message 145, Signal ID 0 is 4.47148348251315

# %%
msgs464_0 = r.get_ts(464,0)
strym.plt_ts(msgs464_0)

# %%
msgs464_1 = r.get_ts(464,1)
strym.plt_ts(msgs464_1)

# %%
msgs464_2 = r.get_ts(464,2)
strym.plt_ts(msgs464_2)

# %%
msgs464_3 = r.get_ts(464,3)
strym.plt_ts(msgs464_3)

# %%
msgs804_1 = r.get_ts(804,0)
strym.plt_ts(msgs464_3)

# %%
msgs804_0 = r.get_ts(804,0)
strym.plt_ts(msgs804_0)

# %%
msgs804_1 = r.get_ts(804,1)
strym.plt_ts(msgs804_1)

# %%
msgs804_2 = r.get_ts(804,2)
strym.plt_ts(msgs804_2)

# %%
msgs464_0
# Out:
#                                        Time  Message
# Clock
# 2020-04-30 16:16:19.191863060  1.588263e+09    63.54
# 2020-04-30 16:16:19.193773985  1.588263e+09    63.56
# 2020-04-30 16:16:19.196507931  1.588263e+09    63.65
# 2020-04-30 16:16:19.198184013  1.588263e+09    63.63
# 2020-04-30 16:16:19.200067997  1.588263e+09    63.68
# ...                                     ...      ...
# 2020-04-30 16:20:33.233618975  1.588264e+09    14.22
# 2020-04-30 16:20:33.253679991  1.588264e+09    14.17
# 2020-04-30 16:20:33.274065018  1.588264e+09    14.26
# 2020-04-30 16:20:33.293877840  1.588264e+09    14.29
# 2020-04-30 16:20:33.314265013  1.588264e+09    13.99
#
# [12748 rows x 2 columns]

# %%
msgs464_0['Message'] = msgs464_0['Message']*1000.0/3600.0
distance = strym.integrate(msgs464_0)

# %%
msgs464_0
# Out:
#                                        Time    Message
# Clock
# 2020-04-30 16:16:19.191863060  1.588263e+09  17.650000
# 2020-04-30 16:16:19.193773985  1.588263e+09  17.655556
# 2020-04-30 16:16:19.196507931  1.588263e+09  17.680556
# 2020-04-30 16:16:19.198184013  1.588263e+09  17.675000
# 2020-04-30 16:16:19.200067997  1.588263e+09  17.688889
# ...                                     ...        ...
# 2020-04-30 16:20:33.233618975  1.588264e+09   3.950000
# 2020-04-30 16:20:33.253679991  1.588264e+09   3.936111
# 2020-04-30 16:20:33.274065018  1.588264e+09   3.961111
# 2020-04-30 16:20:33.293877840  1.588264e+09   3.969444
# 2020-04-30 16:20:33.314265013  1.588264e+09   3.886111
#
# [12748 rows x 2 columns]

# %%
strym.plt_ts(distance)
