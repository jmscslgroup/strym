# %%
import strym
from strym import strymmap
import matplotlib.pyplot as plt
import pandas as pd
import gmplot
import gmaps
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
datafolder='/home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/'
file = '2020-03-12-10-56-10_GPS_Messages.csv'
g = strymmap(csvfile=datafolder+file)
g.dataframe = g.dataframe.dropna()
# Out:
# GPS signal first acquired at 2020-03-12 10:56:20:600000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]

# %%
fig = g.plotroute(interactive=True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1230">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1238">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8943e11f-11f0-4ce9-b7d1-e48952b5758b" data-root-id="1003"></div>

# %%
import glob
parentfolder = '/home/ivory/CyverseData/JmscslgroupData/PandaData/'
folderlist = glob.glob(parentfolder+"*")
csvlist = []
for datafolder in folderlist:
    csvlisttmp = glob.glob(datafolder+"/*.csv")
    for f in csvlisttmp:
        csvlist.append(f)

for index, f in enumerate(csvlist):
    if 'GPS' in f:
        print('{}. File currently being read is {}'.format(index, f))
        g = strymmap(csvfile=f)
        try:
            g.dataframe = g.dataframe.dropna()
        except AttributeError:
            pass
        print('\n')
# Out:
# 2. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_15/2020-03-15-17-32-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-15 17:32:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 4. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_15/2020-03-15-15-12-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-15 15:12:11:600000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 17. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_11/2020-03-11-15-20-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-11 15:20:14:500000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 18. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_11/2020-03-11-10-18-08_GPS_Messages.csv
# GPS signal first acquired at 2020-03-11 10:18:21:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 19. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_11/2020-03-11-11-24-24_GPS_Messages.csv
# GPS signal first acquired at 2020-03-11 11:24:43:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 21. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_11/2020-03-11-12-03-30_GPS_Messages.csv
# GPS signal first acquired at 2020-03-11 12:03:43:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 24. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_11/2020-03-11-16-43-24_GPS_Messages.csv
# GPS signal first acquired at 2020-03-11 16:44:00:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 45. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-10-03-10_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 10:03:30:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 47. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-12-20-31_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 12:20:45:300000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 50. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-11-57-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 11:58:10:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 51. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-10-53-30_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 10:53:39:500000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 53. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-11-31-18_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 11:31:27:600000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 54. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_26/2020-03-26-11-43-41_GPS_Messages.csv
# GPS signal first acquired at 2020-03-26 11:43:52:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 59. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_10/2020-03-10-08-14-04_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 60. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_10/2020-03-10-11-04-13_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 61. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_10/2020-03-10-09-27-18_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 62. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_10/2020-03-10-10-57-06_GPS_Messages.csv
# CSVfile is empty.
#
#
# 64. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-16-55-30_GPS_Messages.csv
# GPS signal first acquired at 2020-03-12 16:55:43:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 65. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-17-01-23_GPS_Messages.csv
# GPS signal first acquired at 2020-03-12 17:01:31:360000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 67. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-09-08-48_GPS_Messages.csv
# GPS signal first acquired at 2020-03-12 09:09:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 68. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-16-42-37_GPS_Messages.csv
# No data was written the csvfile. Not generating map for the drive.
#
#
# 72. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-16-36-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-12 16:36:13:910000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 73. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-10-56-10_GPS_Messages.csv
# GPS signal first acquired at 2020-03-12 10:56:20:600000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 76. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-16-42-33_GPS_Messages.csv
# No data was written the csvfile. Not generating map for the drive.
#
#
# 79. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-17-00-38_GPS_Messages.csv
# GPS failed to acquire satellite signal  during this drive. Not generating map for the drive.
#
#
# 80. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_12/2020-03-12-10-34-00_GPS_Messages.csv
# No data was written the csvfile. Not generating map for the drive.
#
#
# 82. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_13/2020-03-13-06-38-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-13 06:38:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 84. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_13/2020-03-13-11-19-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-13 11:19:13:200000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 86. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_13/2020-03-13-06-53-08_GPS_Messages.csv
# GPS signal first acquired at 2020-03-13 06:53:19:300000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 87. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_13/2020-03-13-11-40-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-13 11:41:10:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 89. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-11-53-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 11:54:10:300000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 90. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-12-27-00_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 12:27:15:200000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 91. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-11-37-30_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 11:37:43:700000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 93. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-10-50-13_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 10:50:29:800000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 94. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-09-14-39_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 09:14:53:200000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 100. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_19/2020-03-19-12-45-44_GPS_Messages.csv
# GPS signal first acquired at 2020-03-19 12:46:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 109. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_22/2020-03-22-08-48-30_GPS_Messages.csv
# GPS signal first acquired at 2020-03-22 08:48:43:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 111. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_22/2020-03-22-11-20-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-22 11:21:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 113. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_09/2020-03-09-17-31-45_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 114. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_09/2020-03-09-15-36-19_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 116. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_09/2020-03-09-18-18-29_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 119. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_09/2020-03-09-19-21-04_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 120. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_29/2020-03-29-08-44-46_GPS_Messages.csv
# GPS signal first acquired at 2020-03-29 08:45:18:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 123. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_29/2020-03-29-12-02-12_GPS_Messages.csv
# GPS signal first acquired at 2020-03-29 12:02:52:800000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 159. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_16/2020-03-16-15-29-20_GPS_Messages.csv
# GPS signal first acquired at 2020-03-16 15:29:37:510000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 171. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-06-34_GPS_DATA.csv
# CSVfile is empty.
#
#
# 172. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-41-20_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 173. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-07-04_GPS_DATA.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 180. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-50-11_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
# 181. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-40-27_GPS_DATA.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 182. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-16-01-41_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 184. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-41-17_GPS_Messages.csv
# CSVfile is empty.
#
#
# 186. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_06/2020-03-06-11-51-28_GPS_Messages.csv
# Ill-formated CSV File. A properly formatted CSV file must have column names as ['Gpstime', 'Status', 'Long', 'Lat', 'Alt', 'HDOP', 'PDOP', 'VDOP']
# Not generating map for the drive route.
#
#
# 232. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_30/2020-03-30-11-54-17_HondaPilot_GPS_Messages.csv
# GPS signal first acquired at 2020-03-30 11:54:44:500000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 255. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_20/2020-03-20-12-59-24_GPS_Messages.csv
# No data was written the csvfile. Not generating map for the drive.
#
#
# 256. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_20/2020-03-20-12-11-24_GPS_Messages.csv
# GPS signal first acquired at 2020-03-20 12:11:39:200000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 259. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_20/2020-03-20-11-53-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-20 11:54:10:110000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 260. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_20/2020-03-20-12-36-18_GPS_Messages.csv
# GPS signal first acquired at 2020-03-20 12:36:25:370000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 274. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_18/2020-03-18-14-52-30_GPS_Messages.csv
# No data was written the csvfile. Not generating map for the drive.
#
#
# 277. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_18/2020-03-18-10-17-18_GPS_Messages.csv
# GPS signal first acquired at 2020-03-18 10:17:40:100000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 278. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_24/2020-03-24-09-03-10_GPS_Messages.csv
# GPS signal first acquired at 2020-03-24 09:03:19:300000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
#
#
# 281. File currently being read is /home/ivory/CyverseData/JmscslgroupData/PandaData/2020_03_24/2020-03-24-16-42-54_GPS_Messages.csv
# GPS signal first acquired at 2020-03-24 16:43:13:900000
#
# Looking for [chromedriver 80.0.3987.106 linux64] driver in cache
# File found in cache by path [/home/ivory/.wdm/drivers/chromedriver/80.0.3987.106/linux64/chromedriver]
